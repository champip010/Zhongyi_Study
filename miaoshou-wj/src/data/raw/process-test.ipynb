# %%
import requests

url='https://mineru.net/api/v4/file-urls/batch'
header = {
    'Content-Type':'application/json',
    'Authorization':'Bearer eyJ0eXBlIjoiSldUIiwiYWxnIjoiSFM1MTIifQ..ru3qwa3FOCHm4dwCtU5RwpuSyVGP2CYZxWaH61Y0ZSaecpyVk7iWEoSagVwOhAYQCBCYm50R7qXbfYU55ac2YQ'
}
data = {
    "enable_formula": True,
    "language": "auto",
    "enable_table": True,
    "files": [
        {"name":"demo.pdf", "is_ocr": True, "data_id": "abcd"}
    ]
    
}
file_path = ["./神经系统调控相关共识/_中药 - 难治性痛风中西医结合治疗专家共识（2023）_司可.pdf"]
try:
    response = requests.post(url,headers=header,json=data)
    if response.status_code == 200:
        result = response.json()
        print('response success. result:{}'.format(result))
        if result["code"] == 0:
            batch_id = result["data"]["batch_id"]
            urls = result["data"]["file_urls"]
            print('batch_id:{},urls:{}'.format(batch_id, urls))
            for i in range(0, len(urls)):
                with open(file_path[i], 'rb') as f:
                    res_upload = requests.put(urls[i], data=f)
                    if res_upload.status_code == 200:
                        print(f"{urls[i]} upload success")
                    else:
                        print(f"{urls[i]} upload failed")
        else:
            print('apply upload url failed,reason:{}'.format(result.msg))
    else:
        print('response not success. status:{} ,result:{}'.format(response.status_code, response))
except Exception as err:
    print(err)
# Out:
# response success. result:{'code': 0, 'msg': 'ok', 'trace_id': 'b5f5d91901c3192510fd0dd62d80fb0d', 'data': {'batch_id': '4e5dc8ff-28e4-4d9c-b584-ccbb8c5fac29', 'file_urls': ['https://mineru.oss-cn-shanghai.aliyuncs.com/api-upload/extract/2025-08-05/4e5dc8ff-28e4-4d9c-b584-ccbb8c5fac29/0968f24b-1f24-4628-a531-2e1ee105d0f3.pdf?Expires=1754471267&OSSAccessKeyId=LTAI5t9nGwatk85zetzojXbn&Signature=CQD5GqtiD3L0o0WL5l0VPm42a7Y%3D']}}
# batch_id:4e5dc8ff-28e4-4d9c-b584-ccbb8c5fac29,urls:['https://mineru.oss-cn-shanghai.aliyuncs.com/api-upload/extract/2025-08-05/4e5dc8ff-28e4-4d9c-b584-ccbb8c5fac29/0968f24b-1f24-4628-a531-2e1ee105d0f3.pdf?Expires=1754471267&OSSAccessKeyId=LTAI5t9nGwatk85zetzojXbn&Signature=CQD5GqtiD3L0o0WL5l0VPm42a7Y%3D']
# ...

# %%
import requests

url = f'https://mineru.net/api/v4/extract-results/batch/4e5dc8ff-28e4-4d9c-b584-ccbb8c5fac29'
header = {
    'Content-Type':'application/json',
    'Authorization':'Bearer eyJ0eXBlIjoiSldUIiwiYWxnIjoiSFM1MTIifQ..ru3qwa3FOCHm4dwCtU5RwpuSyVGP2CYZxWaH61Y0ZSaecpyVk7iWEoSagVwOhAYQCBCYm50R7qXbfYU55ac2YQ'
}

res = requests.get(url, headers=header)
print(res.status_code)
print(res.json())
print(res.json()["data"])
# Out:
# 200
# {'code': 0, 'msg': 'ok', 'trace_id': 'f1c8d0a50e23dc57964713ff66291375', 'data': {'batch_id': '4e5dc8ff-28e4-4d9c-b584-ccbb8c5fac29', 'extract_result': [{'data_id': 'abcd', 'file_name': 'demo.pdf', 'state': 'done', 'err_msg': '', 'full_zip_url': 'https://cdn-mineru.openxlab.org.cn/pdf/2025-08-05/8adfa81e-2368-4bd6-aa60-eb8b93024491.zip'}]}}
# {'batch_id': '4e5dc8ff-28e4-4d9c-b584-ccbb8c5fac29', 'extract_result': [{'data_id': 'abcd', 'file_name': 'demo.pdf', 'state': 'done', 'err_msg': '', 'full_zip_url': 'https://cdn-mineru.openxlab.org.cn/pdf/2025-08-05/8adfa81e-2368-4bd6-aa60-eb8b93024491.zip'}]}

# %%
import os
base = "./专家共识与指南"
print(os.path.join(base, "test.txt"))
print(os.listdir(base))
print(os.path.basename("base/test.txt"))
# Out:
# ./专家共识与指南/test.txt
# ...

# %%
import os
base = "./专家共识与指南"
for root, dirs, files in os.walk(base):
    print(type(root),f'{root}')
    print(type(dirs),f'{dirs}')
    print(type(files),f'{files}')
# Out:
# <class 'str'> ./专家共识与指南
# <class 'list'> ['《脑出血中医健康管理指南》公示稿', '股骨头坏死中医辨证标准', '《心力衰竭中医健康管理指南》公示稿', '1-18项中西医结合诊疗方案-公示稿', '37-52项中西医结合诊疗方案-公示稿', '股骨头坏死中医疗效评价标准', '1.《中医药临床试验核心指标集研制技术规范》等3项拟发布团体标准公示相关资料', '《骨关节炎病证结合诊疗指南》公开征求意见相关资料', '19-36项中西医结合诊疗方案-公示稿', '慢性阻塞肺疾病中医诊疗指南', '《心肌梗死中医健康管理指南》公示稿', '《稳定型心绞痛中医健康管理指南》公示稿', '《脑梗死中医健康管理指南》公示稿', '附件：《中医药整体证据研究的标准化操作规程》拟发布团体标准公示相关材料']
# <class 'list'> []
# <class 'str'> ./专家共识与指南/《脑出血中医健康管理指南》公示稿
# <class 'list'> []
# <class 'list'> ['《脑出血中医健康管理指南》公示稿.pdf', '《脑出血中医健康管理指南》编制说明.pdf']
# <class 'str'> ./专家共识与指南/股骨头坏死中医辨证标准
# <class 'list'> []
# <class 'list'> ['4.1-送审稿-股骨头坏死中医辨证标准.pdf', '4.2-《股骨头坏死中医辨证标准》+编制说明.pdf']
# <class 'str'> ./专家共识与指南/《心力衰竭中医健康管理指南》公示稿
# <class 'list'> []
# <class 'list'> ['《心力衰竭中医健康管理指南》公示稿.pdf', '《心力衰竭中医健康管理指南》编制说明.pdf']
# <class 'str'> ./专家共识与指南/1-18项中西医结合诊疗方案-公示稿
# <class 'list'> []
# ...

# %%
import re
f = os.path.basename("base/test.txt")
# 只保留字母、数字、下划线、短划线、英文句号
raw_id = os.path.splitext(f)[0]
valid_id = re.sub(r"[^A-Za-z0-9_.-]", "_", raw_id)
valid_id = valid_id[:128]
print(valid_id)
print(raw_id)
# Out:
# test
# test

# %%
import time
# 无flush（可能看到突然出现大段文字）
print("Hello", end=""); time.sleep(1); print("World") 

# 有flush（实时显示）
print("Hello", end="", flush=True); time.sleep(1); print("World")
# Out:
# HelloWorld
# HelloWorld
